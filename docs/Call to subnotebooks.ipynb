# %%
import papermill as pm

# Ruta al notebook secundario
notebook_path = '/content/drive/MyDrive/path/to/your/notebook.ipynb'

# Parámetros para el notebook secundario
parameters = {
    'param1': value1,
    'param2': value2,
    # Agrega aquí todos los parámetros necesarios
}

# Ejecutar el notebook secundario y guardar el resultado en un nuevo notebook
output_notebook_path = '/content/drive/MyDrive/path/to/output_notebook.ipynb'
pm.execute_notebook(notebook_path, output_notebook_path, parameters=parameters)

# Leer el resultado del notebook secundario
output_notebook = pm.read_notebook(output_notebook_path)

# Obtener la salida de la última celda del notebook secundario
last_cell = output_notebook.cells[-1]
output = last_cell.outputs

# Mostrar la salida
for out in output:
    print(out)
