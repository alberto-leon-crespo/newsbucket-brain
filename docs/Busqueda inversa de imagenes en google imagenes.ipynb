# %%
# !pip install pywhatkit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
from googlesearch import search_images

# Definir la URL de la imagen que deseas buscar (puede ser una imagen en línea o local)
image_url = "https://cloudfront-eu-central-1.images.arcpublishing.com/prisa/J32UN3N5ENDBBBC7IHYKCT2JOQ.jpg"

# Realizar la búsqueda inversa de la imagen
search_results = search_images(image_url)
# Imprimir los resultados
for result in search_results:
    print(result)
# Out:
# https://www.cadenalaser.com/2023/06/10/invitaciones-digitales-drones-y-ceremonias-por-streaming-asi-irrumpe-la-tecnologia-en-las-bodas/
# https://aws.amazon.com/cloudfront/
# https://aws.amazon.com/cn/blogs/china/cloudfront-errors-solutions/
# https://elpais.com/noticias/aviones-no-tripulados/
# https://gerente.com/ve/new-rss/alacran-luis-ratti-anuncia-recurso-de-amparo-contra-la-primaria/cloudfront-eu-central-1-images-arcpublishing-1-2-png/
# https://elpais.com/noticias/paginas-web/
# https://aws.amazon.com/cn/blogs/china/use-cloudfront-lambdaedge-for-transaction-processing/
# https://newsrnd.com/tech/2023-06-07-kate-darling--robot-expert--%22we-shouldn-t-laugh-at-people-who-fall-in-love-with-a-machine--it-will-happen-to-all-of-us-%22.H1-_teyRLh.html
# https://elpais.com/hemeroteca/2023-06-10/4/
# https://www.infoq.cn/article/fexbqa53ubraliips2st
# https://elpais.com/noticias/matrimonio/
# https://elpais.com/autor/victoria-toro/
# ...
